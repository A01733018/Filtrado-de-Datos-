# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_csv('listings.csv')
df
# Out:
#                         id                                       listing_url  \
# 0                   538175               https://www.airbnb.com/rooms/538175
# 1                   541221               https://www.airbnb.com/rooms/541221
# 2                   541668               https://www.airbnb.com/rooms/541668
# 3                   544809               https://www.airbnb.com/rooms/544809
# 4                   553285               https://www.airbnb.com/rooms/553285
# ...                    ...                                               ...
# 22535  1444043842204694335  https://www.airbnb.com/rooms/1444043842204694335
# 22536  1444134511111522063  https://www.airbnb.com/rooms/1444134511111522063
# 22537  1444209901012550835  https://www.airbnb.com/rooms/1444209901012550835
# 22538  1444251694855590556  https://www.airbnb.com/rooms/1444251694855590556
# 22539  1444265456512525732  https://www.airbnb.com/rooms/1444265456512525732
#
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22540 entries, 0 to 22539
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            22540 non-null  int64
#  1   listing_url                                   22540 non-null  object
#  2   scrape_id                                     22540 non-null  int64
#  3   last_scraped                                  22540 non-null  object
#  4   source                                        22540 non-null  object
#  5   name                                          22540 non-null  object
#  6   description                                   22077 non-null  object
#  7   neighborhood_overview                         10690 non-null  object
#  8   picture_url                                   22540 non-null  object
# ...

# %% [markdown]
# ***a) Los registros de 5 “host name” diferentes***

# %%
#Filtro o
filtro=df[(df["host_name"] == "Barbara") | (df["host_name"] == "Elena") | (df["host_name"] == "Tony") | (df["host_name"] == "Rita")  | (df["host_name"] == "Sonia") ]  
filtro
# Out:
#                         id                                       listing_url  \
# 0                   538175               https://www.airbnb.com/rooms/538175
# 1                   541221               https://www.airbnb.com/rooms/541221
# 7                   579191               https://www.airbnb.com/rooms/579191
# 8                   584568               https://www.airbnb.com/rooms/584568
# 18                  143329               https://www.airbnb.com/rooms/143329
# ...                    ...                                               ...
# 21296  1394091373047483088  https://www.airbnb.com/rooms/1394091373047483088
# 21458  1402608993596804083  https://www.airbnb.com/rooms/1402608993596804083
# 21479  1403581080308050466  https://www.airbnb.com/rooms/1403581080308050466
# 21846  1417202192530775976  https://www.airbnb.com/rooms/1417202192530775976
# 22022  1426992227822301548  https://www.airbnb.com/rooms/1426992227822301548
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro.to_csv("Act4.2_Ej1.csv")

# %% [markdown]
# ***b) Los registros de los host que se hallan unido a Airbnb “despues del año 2020”***

# %%
#Filtro por objeto
filtro2=df[df["host_since"] > "2020-12-31"]
filtro2
# Out:
#                         id                                       listing_url  \
# 118                 431719               https://www.airbnb.com/rooms/431719
# 1191               8143087              https://www.airbnb.com/rooms/8143087
# 1352               9248162              https://www.airbnb.com/rooms/9248162
# 2405              22479353             https://www.airbnb.com/rooms/22479353
# 2598              24284420             https://www.airbnb.com/rooms/24284420
# ...                    ...                                               ...
# 22526  1443231743398303611  https://www.airbnb.com/rooms/1443231743398303611
# 22527  1443291150461235073  https://www.airbnb.com/rooms/1443291150461235073
# 22532  1443521755716329506  https://www.airbnb.com/rooms/1443521755716329506
# 22535  1444043842204694335  https://www.airbnb.com/rooms/1444043842204694335
# 22538  1444251694855590556  https://www.airbnb.com/rooms/1444251694855590556
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro2.to_csv("Act4.2_Ej2.csv")

# %% [markdown]
# ***c) Los registros de los host que responden “a más tardar en 1 día”***

# %%
#Filtro por objeto
filtro3=df[df["host_response_time"] == "within an hour"]
filtro3
# Out:
#                         id                                       listing_url  \
# 2                   541668               https://www.airbnb.com/rooms/541668
# 3                   544809               https://www.airbnb.com/rooms/544809
# 4                   553285               https://www.airbnb.com/rooms/553285
# 6                   566637               https://www.airbnb.com/rooms/566637
# 10                   40470                https://www.airbnb.com/rooms/40470
# ...                    ...                                               ...
# 22533  1443573371955257267  https://www.airbnb.com/rooms/1443573371955257267
# 22534  1444038831959759573  https://www.airbnb.com/rooms/1444038831959759573
# 22536  1444134511111522063  https://www.airbnb.com/rooms/1444134511111522063
# 22537  1444209901012550835  https://www.airbnb.com/rooms/1444209901012550835
# 22539  1444265456512525732  https://www.airbnb.com/rooms/1444265456512525732
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro3.to_csv("Act4.2_Ej3.csv")

# %% [markdown]
# ***d) Los registros de las filas “Múltiplos de 200… (400, 600, 800, etc.)”***

# %%
filtro4 = df.iloc[0::200,:]
filtro4
# Out:
#                         id                                       listing_url  \
# 0                   538175               https://www.airbnb.com/rooms/538175
# 200                1071178              https://www.airbnb.com/rooms/1071178
# 400                2649847              https://www.airbnb.com/rooms/2649847
# 600                4990673              https://www.airbnb.com/rooms/4990673
# 800                5472693              https://www.airbnb.com/rooms/5472693
# ...                    ...                                               ...
# 21600  1410369265974221350  https://www.airbnb.com/rooms/1410369265974221350
# 21800  1416490434523038787  https://www.airbnb.com/rooms/1416490434523038787
# 22000  1423110490680077926  https://www.airbnb.com/rooms/1423110490680077926
# 22200  1433941963196006923  https://www.airbnb.com/rooms/1433941963196006923
# 22400  1437519521349394185  https://www.airbnb.com/rooms/1437519521349394185
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("Act4.2_Ej4.csv")

# %% [markdown]
# ***e) Los registros de los tipos de cuarto: “Entire home” y “Private room”***

# %%
#Filtro o
filtro5=df[(df["room_type"] == "Entire home/apt") | (df["room_type"] == "Private room")]
filtro5
# Out:
#                         id                                       listing_url  \
# 0                   538175               https://www.airbnb.com/rooms/538175
# 1                   541221               https://www.airbnb.com/rooms/541221
# 2                   541668               https://www.airbnb.com/rooms/541668
# 3                   544809               https://www.airbnb.com/rooms/544809
# 4                   553285               https://www.airbnb.com/rooms/553285
# ...                    ...                                               ...
# 22535  1444043842204694335  https://www.airbnb.com/rooms/1444043842204694335
# 22536  1444134511111522063  https://www.airbnb.com/rooms/1444134511111522063
# 22537  1444209901012550835  https://www.airbnb.com/rooms/1444209901012550835
# 22538  1444251694855590556  https://www.airbnb.com/rooms/1444251694855590556
# 22539  1444265456512525732  https://www.airbnb.com/rooms/1444265456512525732
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro5.to_csv("Act4.2_Ej5.csv")

# %%
pd.options.display.max_columns =None

# %% [markdown]
# ***f) Los registros que “a lo mucho cuenten con 4 camas”***

# %%
#Filtro por comparacion
filtro6=df[df["beds"] <=4]
filtro6
# Out:
#                         id                                       listing_url  \
# 0                   538175               https://www.airbnb.com/rooms/538175
# 1                   541221               https://www.airbnb.com/rooms/541221
# 2                   541668               https://www.airbnb.com/rooms/541668
# 3                   544809               https://www.airbnb.com/rooms/544809
# 4                   553285               https://www.airbnb.com/rooms/553285
# ...                    ...                                               ...
# 22535  1444043842204694335  https://www.airbnb.com/rooms/1444043842204694335
# 22536  1444134511111522063  https://www.airbnb.com/rooms/1444134511111522063
# 22537  1444209901012550835  https://www.airbnb.com/rooms/1444209901012550835
# 22538  1444251694855590556  https://www.airbnb.com/rooms/1444251694855590556
# 22539  1444265456512525732  https://www.airbnb.com/rooms/1444265456512525732
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro6.to_csv("Act4.2_Ej6.csv")

# %% [markdown]
# ***g) Los registros que “sean superhost”***

# %%
#Filtro por comparacion
filtro8=df[df["host_is_superhost"] == "t"]
filtro8
# Out:
#                         id                                       listing_url  \
# 2                   541668               https://www.airbnb.com/rooms/541668
# 4                   553285               https://www.airbnb.com/rooms/553285
# 6                   566637               https://www.airbnb.com/rooms/566637
# 15                  102817               https://www.airbnb.com/rooms/102817
# 16                  122514               https://www.airbnb.com/rooms/122514
# ...                    ...                                               ...
# 22521  1442767962385375491  https://www.airbnb.com/rooms/1442767962385375491
# 22528  1443307020601196438  https://www.airbnb.com/rooms/1443307020601196438
# 22529  1443420355372697776  https://www.airbnb.com/rooms/1443420355372697776
# 22532  1443521755716329506  https://www.airbnb.com/rooms/1443521755716329506
# 22537  1444209901012550835  https://www.airbnb.com/rooms/1444209901012550835
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro8.to_csv("Act4.2_Ej8.csv")

# %% [markdown]
# ***h) Los registros de las columnas “impares”***

# %%
filtro9 = df.iloc[1::2]
filtro9
# Out:
#                         id                                       listing_url  \
# 1                   541221               https://www.airbnb.com/rooms/541221
# 3                   544809               https://www.airbnb.com/rooms/544809
# 5                   564917               https://www.airbnb.com/rooms/564917
# 7                   579191               https://www.airbnb.com/rooms/579191
# 9                    23986                https://www.airbnb.com/rooms/23986
# ...                    ...                                               ...
# 22531  1443470436868103701  https://www.airbnb.com/rooms/1443470436868103701
# 22533  1443573371955257267  https://www.airbnb.com/rooms/1443573371955257267
# 22535  1444043842204694335  https://www.airbnb.com/rooms/1444043842204694335
# 22537  1444209901012550835  https://www.airbnb.com/rooms/1444209901012550835
# 22539  1444265456512525732  https://www.airbnb.com/rooms/1444265456512525732
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Act4.2_Ej9.csv")
